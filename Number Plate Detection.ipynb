# %% [markdown]
# # Number Plate Detection Using YOLOv8
#
# Author: Abdul Rehman\
# Date:   3-Sep-2024
#
# [![Email](https://img.shields.io/badge/Gmail-Contact-red)](mailto:inboxx.abdulrehman@gamil.com)&nbsp;&nbsp;
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Connect-blue)](http://www.linkedin.com/in/abdul-rehman-052292271)&nbsp;&nbsp;
# [![Twitter](https://img.shields.io/badge/Twitter-Follow-blue)](https://twitter.com/AbdulRehman_twt)&nbsp;&nbsp;
# [![GitHub](https://img.shields.io/badge/GitHub-Follow-lightgrey)](https://github.com/AbdulRehman-git?tab=repositories)&nbsp;

# %% [markdown]
# ## Introduction

# %% [markdown]
# This project aims to detect number plates in images using the YOLOv8 object detection model. YOLO (You Only Look Once) is a state-of-the-art, real-time object detection system. YOLOv8 is the latest version, offering improved accuracy and speed.

# %% [markdown]
# ## Dataset

# %% [markdown]
# The dataset consists of approximately 1,000+ images, each labeled with the location of number plates. The dataset is split into three parts: training, validation, and testing.
#
# - **Training Set:** 85% of the dataset
# - **Validation Set:** 9% of the dataset
# - **Testing Set:** 6% of the dataset

# %% [markdown]
# ## Objective

# %% [markdown]
# - **Real-Time Number Plate Detection:** Implement a system capable of detecting number plates in real-time from a video feed or a batch of images.
# - **YOLOv8 Model for Object Detection:** Utilize the YOLOv8 model, renowned for its high speed and accuracy, to detect number plates in various image conditions.
# - **Dataset Preparation and Management:** Organize and preprocess a labeled dataset of approximately 1,000 images, splitting it into training, validation, and testing sets for effective model training and evaluation.
# - **Training and Resuming Model:** Train the YOLOv8 model, ensuring checkpoints are saved periodically to Google Drive. Enable resuming training from the last checkpoint in case of interruptions.
# - **Performance Evaluation:** Assess the model’s performance using metrics such as precision, recall, and mean Average Precision (mAP) to ensure high accuracy and reliability.
# - **Bounding Box Visualization:** Draw bounding boxes around detected number plates with labels indicating the identified number plate and confidence score.

# %% [markdown]
# ## Tools and Technologies

# %% [markdown]
# **YOLOv8 (You Only Look Once, version 8)**
#
# - **Why YOLOv8?** YOLOv8 is a state-of-the-art object detection model that offers a good balance between speed and accuracy, making it ideal for real-time applications.
# - **Usage:** YOLOv8 will be used to detect license plates from the captured video frames.
#
# **OpenCV**
#
# - **Why OpenCV?** OpenCV (Open Source Computer Vision Library) is a powerful library for computer vision tasks. It is used for image processing, video capture, and analysis.
# - **Usage:** OpenCV will be used to handle the video feed, preprocess images, and draw bounding boxes on detected license plates.
#
# **Google Colab**
#
# - **Why Google Colab?** Google Colab provides a free cloud-based environment with GPU support, making it convenient for developing and testing deep learning models.
# - **Usage:** Google Colab will be used to run the notebook and perform the computations required for real-time license plate detection and text recognition.

# %% [markdown]
# ## Implementation Steps

# %% [markdown]
# 1. **Install Required Packages**: Begin by installing all necessary libraries and dependencies to ensure the environment is properly set up for running the project.
#
# 2. **Load the YOLOv8 Model**: Load the pre-trained YOLOv8 model, fine-tuned specifically for detecting and recognizing license plates.
#
# 3. **Detect License Plates**: Utilize the YOLOv8 model to detect license plates within each video frame, focusing on identifying bounding boxes around detected plates.
#
# 4. **Extract Text from License Plates**: Apply OCR techniques (e.g., PaddleOCR) to extract and recognize text within the detected license plate bounding boxes.
#
# 5. **Visualize Results**: Overlay bounding boxes and display the extracted text on the video frames, providing clear visual indicators of detected license plates and their associated text.
#
# 6. **Save and Display Output**: Construct a DataFrame to store the detected text along with the corresponding video frames, and display the processed video with bounding boxes in the notebook for review.

# %% [markdown]
# ## Expected Outcome

# %% [markdown]
# By the end of this project, we will have a functional system that can:
#
# - Capture real-time video feed.
# - Extract and recognize text from the detected license plates.
# - Display the results with bounding boxes and labels indicating the extracted text.
#
# This project demonstrates the application of advanced computer vision techniques for real-time object detection and text recognition, showcasing the practical use of deep learning models like YOLOv8 and OCR tools.

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Installing required libraries

# %%
# !pip install ultralytics

# Ultralytics is a powerful library for state-of-the-art object detection and image segmentation using YOLO models.

# %% [markdown]
# ## Mounting google drive to colab

# %%
from google.colab import drive

drive.mount('/content/drive')

# %% [markdown]
# ## Importing required libraries

# %%
import os
import random
from shutil import copy2
import cv2
from ultralytics import YOLO
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display, clear_output

# %% [markdown]
# ## First Training
#
#
# ### epoch 1 to 43

# %%
# Load YOLOv8 model
model = YOLO('yolov8n.pt')

# Path to save the training results
project_path = '/content/drive/MyDrive/ANPR/data'

# Train the model
model.train(data='/content/drive/MyDrive/ANPR/data/data.yaml', 
            # The data.yaml file contains dataset paths, classes, and other configuration details required for YOLO training.
            epochs=50, # Number of training epochs to run, controlling how many times the model sees the entire dataset.
            batch=1, # Batch size, or the number of images processed at once during training.
            imgsz=1280, # Image size to which the input images are resized before feeding them into the model.
            save_period=1, # Saves model checkpoints every 'save_period' epochs.
            project=project_path, # Directory path where training results, such as models and logs, will be saved.
            name='number_plate_detection') # Name of the training run, used to create a folder under the project directory.
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## 2nd Training
#
# ### epoch 43 to 51

# %%
from ultralytics import YOLO

# Load YOLOv8 model with the checkpoint
model = YOLO('/content/drive/MyDrive/ANPR/data/number_plate_detection/weights/last.pt')
# Now here we will initialize the model with last weight of above training.

# Path to save the resumed training results
project_path = '/content/drive/MyDrive/ANPR/data'

# Train the model
model.train(data='/content/drive/MyDrive/ANPR/data/data.yaml',
            epochs=50,
            batch=1,
            imgsz=1280,
            save_period=1,
            project=project_path,
            name='number_plate_detection',
            resume=True)
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## 3rd Training
#
# ### epoch 50 to 80

# %%
from ultralytics import YOLO

# Load YOLOv8 model with the checkpoint
model = YOLO('/content/drive/MyDrive/ANPR/data/number_plate_detection/weights/epoch50.pt')

# Path to save the resumed training results
project_path = '/content/drive/MyDrive/ANPR/data'

model.train(data='/content/drive/MyDrive/ANPR/data/data.yaml',
            epochs=100,
            batch=1,
            imgsz=1280,
            save_period=1,
            project=project_path,
            name='number_plate_detection',
            resume=True)
# Out:
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Statistics
#
# As YOLO automatically saves the model's statistics and performance metrics in the specified directory, we will now review and analyze these results.

# %%
# Load the results.csv file
results_path = 'results.csv' # change it according to yours

df = pd.read_csv(results_path)

# %% [markdown]
# df.columns

# %% [markdown]
# As you can see, there are multiple blank spaces in the column names. We need to remove them for proper data handling.

# %%
df.columns = df.columns.str.strip() # Remove leading/trailing spaces from column names

df.columns
# Out:
# Index(['epoch', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')

# %% [markdown]
# Here you can see that we have successfully remove all the spaces.

# %% [markdown]
# ### Let's now visualize the results.

# %%
plt.figure(figsize=(10, 6))  # Set the figure size for the plot

plt.plot(df['epoch'], df['train/box_loss'], label='Train Box Loss')  # Plot training box loss over epochs

plt.plot(df['epoch'], df['train/cls_loss'], label='Train Class Loss')  # Plot training class loss over epochs

plt.plot(df['epoch'], df['val/box_loss'], label='Val Box Loss')  # Plot validation box loss over epochs

plt.plot(df['epoch'], df['val/cls_loss'], label='Val Class Loss')  # Plot validation class loss over epochs

plt.xlabel('Epoch')  # Label the x-axis as 'Epoch'

plt.ylabel('Loss')  # Label the y-axis as 'Loss'

plt.title('Training and Validation Loss')  # Set the title of the plot

plt.legend()  # Add a legend to the plot

plt.grid(True)  # Enable grid lines for better readability

plt.show()  # Display the plot

# %% [markdown]
# ### Displaying the detailed graph

# %%
results_img = "results.png" # path of image

display(Image(results_img))

# %%
# Confusion Matrix
display(Image("confusion_matrix.png"))

# %% [markdown]
# ## Testing the Model and Extracting License Plate

# %% [markdown]
# ### Load the best weights of trained YOLO

# %%
model = YOLO("epoch80.pt")

# %% [markdown]
# ### Test model on image files

# %%
image_path = 'c.jpg' # set the path of file
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

# Make predictions
results = model.predict(image_path)

# Plot the image with predictions
fig, ax = plt.subplots(figsize=(8, 8))
ax.imshow(image)
ax.axis('off')  # Hide axes
ax.set_title('Predictions on Image')

# Plot the bounding boxes and labels
for result in results:
    boxes = result.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]
        ax.add_patch(plt.Rectangle((x1, y1), x2-x1, y2-y1, fill=False, edgecolor='blue', linewidth=2))
        label = f"{result.names[int(box.cls[0])]}: {box.conf[0]:.2f}"
        ax.text(x1, y1, label, fontsize=6, color='white', bbox=dict(facecolor='blue', edgecolor='blue', alpha=False))

plt.show()
# Out:
# image 1/1 /home/abdulrehman/dev/ML1/No.Plate_Detection/c.jpg: 1248x1280 3 License_Plates, 1036.0ms
# Speed: 43.8ms preprocess, 1036.0ms inference, 1.8ms postprocess per image at shape (1, 3, 1248, 1280)

# %% [markdown]
# ## Using Paddle OCR

# %%
# Install Paddle OCR

# !pip install paddlepaddle
# !pip install paddleocr

# %%
# Initialize PaddleOCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')  # Specify the language you want to use
# Out:
# [2024/09/03 13:47:16] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='/home/abdulrehman/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/home/abdulrehman/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6,
# ...

# %%
# Set the folder path containing the images
folder_path = 'car_testing' # give a folder of different images

# %%
# Get the list of all image files in the folder

image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.lower().endswith(('.jpg', '.png', '.jpeg', '.webp'))]

# %% [markdown]
# ### Displaying 5 random images from folder

# %%
# Number of random images to display
num_random_images = 5

# Select a random sample of image files
random_images = random.sample(image_files, min(num_random_images, len(image_files)))

# Create a figure with subplots
num_rows = (len(random_images) + 1) // 2  # Calculate number of rows needed
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 12))

# Display each random image
for i, image_file in enumerate(random_images):
    image_path = os.path.join(folder_path, image_file)
    image = cv2.imread(image_path)
    
    if image is None:
        continue

    # Convert BGR image to RGB for display
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Make predictions using the YOLO model
    results = model(image_path)
    
    # Draw bounding boxes on the image
    for result in results:
        if len(result.boxes) > 0:
            for box in result.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cv2.rectangle(image_rgb, (x1, y1), (x2, y2), (0, 255, 0), 2)
    
    # Determine the subplot location
    row = i // 2
    col = i % 2
    axes[row, col].imshow(image_rgb)
    axes[row, col].axis('off')
    axes[row, col].set_title(image_file)

# Hide any unused subplots
for j in range(len(random_images), num_rows * 2):
    axes[j // 2, j % 2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# image 1/1 /home/abdulrehman/dev/ML1/No.Plate_Detection/car_testing/c.jpg: 1248x1280 3 License_Plates, 686.3ms
# Speed: 20.6ms preprocess, 686.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1248, 1280)
#
# image 1/1 /home/abdulrehman/dev/ML1/No.Plate_Detection/car_testing/DSC_0971.JPG: 1184x1280 1 License_Plate, 833.4ms
# Speed: 23.8ms preprocess, 833.4ms inference, 1.9ms postprocess per image at shape (1, 3, 1184, 1280)
#
# image 1/1 /home/abdulrehman/dev/ML1/No.Plate_Detection/car_testing/DSC_0969.JPG: 1056x1280 1 License_Plate, 540.8ms
# Speed: 24.1ms preprocess, 540.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1056, 1280)
#
# image 1/1 /home/abdulrehman/dev/ML1/No.Plate_Detection/car_testing/DSC_0971x.jpg: 1216x1280 1 License_Plate, 873.7ms
# Speed: 20.6ms preprocess, 873.7ms inference, 1.7ms postprocess per image at shape (1, 3, 1216, 1280)
#
# ...

# %% [markdown]
# ## Extracting text from number plat

# %%
# List to store results
results_list = []

for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Could not load image {image_file}")
        continue

    # Make predictions using the YOLO model
    results = model(image_path)
    
    text_lines = []
    number_plate_detected = False

    # Iterate over the results
    for result in results:
        if len(result.boxes) == 0:
            print(f"No number plates detected in {image_file}")
            continue
        
        number_plate_detected = True

        # Extract text from each bounding box
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cropped_image = image[y1:y2, x1:x2]
            
            # Convert cropped image to RGB for PaddleOCR
            cropped_image_rgb = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)

            # Apply OCR to the cropped image
            ocr_results = ocr.ocr(cropped_image_rgb, cls=True)
            
            # Collect the detected text
            for line in ocr_results[0]:
                _, (text, confidence) = line
                text_lines.append(text)  # Collect all detected texts

    # Join all detected lines into a single string
    full_text = ' '.join(text_lines) if text_lines else 'No text detected'

    # Add the results to the list
    results_list.append((image_file, full_text))

# clear output
clear_output(wait=True)

# Create a DataFrame to store the extracted license plate texts
results_df = pd.DataFrame(results_list, columns=['Filename', 'Extracted Text'])

# Display the DataFrame
print(results_df)
# Out:
#          Filename                           Extracted Text
# 0    DSC_0968.JPG                              LEA-16 1856
# 1    DSC_0988.JPG                     ICT VX-814 ISLAMABAD
# 2    DSC_0985.JPG                                   MN.484
# 3   DSC_0973x.jpg                                  BFM-731
# 4   DSC_0971x.jpg                              MNA-0B 2206
# 5    DSC_0982.JPG                     ADVOCATE LEB-18 1194
# 6    DSC_0969.JPG                              MNA-08 3685
# 7    DSC_0975.JPG                                  LET5280
# 8    DSC_0996.JPG                              BRS-12 1500
# 9    DSC_0997.JPG                                MNA17 486
# 10   DSC_0994.JPG                                 FSA 5750
# 11   DSC_0970.JPG                                 LWK 5850
# 12   DSC_0971.JPG                        TKHHB POUCE VR287
# 13   DSC_0984.JPG                                 LEC 1487
# 14   DSC_0990.JPG                              MNA-08 5007
# ...

# %%
# Saving above resuluts_df

results_df.to_csv("extracted_text", index=False) # "indext=False" to save CSV file without including row indices

# %% [markdown]
# ## Conclusion
#
# **In this task, we successfully extracted license plate texts from images using YOLOv8 and PaddleOCR, achieving promising results that demonstrate the potential for further application and training. To enhance the model's performance, a more extensive dataset could be utilized, and alternative OCR solutions, such as Google OCR, which offer improved speed and accuracy, could be explored.**
